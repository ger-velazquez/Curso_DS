# %% [markdown]
# Vamos a jugar un poco con python y Pandas.
#
# Me bajé, del repositorio de datos de la ciudad de Buenos Aires, un listado completo de universidades con sede en CABA y sus unidades académicas: https://data.buenosaires.gob.ar/dataset/universidades
#
# Vamos a ver qué podemos hacer con eso...

# %% [markdown]
# Primero vamos a importar pandas, para procesar el CSV como dataset

# %%
import pandas as pd

# %% [markdown]
# Vamos a levantar el CSV y a revisar qué tiene...

# %%
universidades_data = pd.read_csv('./universidades.csv')
universidades_data.head()
# Out:
#    regimen                                         universida  univ_c  \
# 0  Privado  FLACSO (Facultad Latinoamericana de Ciencias S...       1
# 1  Privado              Instituto Tecnológico de Buenos Aires       2
# 2  Privado              Instituto Tecnológico de Buenos Aires       2
# 3  Privado              Instituto Tecnológico de Buenos Aires       2
# 4  Privado              Instituto Tecnológico de Buenos Aires       2
#
#                       unidad_aca  unac_c  anexo_c  unicue   cui  \
# 0                      Rectorado       1        0  100100  2546
# 1                      Rectorado       1        0  200100  2456
# 2  Departamento de Investigación       7        0  200700  2456
# 3                Área de Energía      40        0  204000  2456
# 4  Departamento de Bioingeniería      87        0  208700  2456
#
#                     telef        fax    ...              direccion_norm  \
# 0  5238-9339 (C)5238-9300  4375-1373    ...                Ayacucho 555
# 1   63934813 [C]6393-4810  6393-4813    ...      Av. Eduardo Madero 399
# 2               6393-4869  6393-4869    ...      Av. Eduardo Madero 399
# 3               6393-4870  6393-4870    ...      Av. Eduardo Madero 399
# 4               6393-4893  6393-4893    ...      Av. Eduardo Madero 399
#
#                  calle altura                                     WKT_gkba  \
# 0            Ayacucho     555  POINT (-58.3953412190814 -34.6026584750106)
# 1  Av. Eduardo Madero     399  POINT (-58.3678488464698 -34.6031162314776)
# 2  Av. Eduardo Madero     399  POINT (-58.3678488464698 -34.6031162314776)
# 3  Av. Eduardo Madero     399  POINT (-58.3678488464698 -34.6031162314776)
# 4  Av. Eduardo Madero     399  POINT (-58.3678488464698 -34.6031162314776)
#
#           barrio    comuna codigo_postal  codigo_postal_argentino       long  \
# 0      Balvanera  Comuna 3        1026.0                 C1026AAC -58.395341
# 1  Puerto Madero  Comuna 1        1106.0                 C1106ACD -58.367849
# 2  Puerto Madero  Comuna 1        1106.0                 C1106ACD -58.367849
# 3  Puerto Madero  Comuna 1        1106.0                 C1106ACD -58.367849
# 4  Puerto Madero  Comuna 1        1106.0                 C1106ACD -58.367849
#
#          lat
# 0 -34.602658
# 1 -34.603116
# 2 -34.603116
# 3 -34.603116
# 4 -34.603116
#
# [5 rows x 21 columns]

# %% [markdown]
# Para romper los huevos, veamos de qué tipo es el listado (dataframe, obvio)

# %%
type(universidades_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Dado que cada universidad tiene muchas sedes, vamos a ver dónde tienen sus rectorados

# %%
rectorados = universidades_data[universidades_data['unidad_aca'] == 'Rectorado']
print(rectorados)
# Out:
#      regimen                                         universida  univ_c  \
# 0    Privado  FLACSO (Facultad Latinoamericana de Ciencias S...       1
# 1    Privado              Instituto Tecnológico de Buenos Aires       2
# 28   Privado                      Instituto Universitario CEMIC       4
# 31   Privado  Instituto Universitario de Ciencias de la Salu...       5
# 33   Público    Instituto Universitario de Gendarmería Nacional       6
# 35   Público  Instituto Universitario de la Policía Federal ...       7
# 53   Privado  Instituto Universitario de Salud Mental de la ...       8
# 59   Público      Instituto Universitario de Seguridad Marítima       9
# 61   Público  Instituto Universitario del Ejército "Mayor Fr...      10
# 64   Privado  Instituto Universitario Escuela Argentina de N...      11
# 72   Privado  Instituto Universitario Escuela de Medicina de...      12
# 81   Privado  Instituto Universitario Escuela Superior de Ec...      13
# 88   Privado                     Instituto Universitario ISEDET      14
# 94   Público  Instituto Universitario Nacional de Derechos H...      15
# 104  Privado                Instituto Universitario River Plate      17
# 107  Privado  Pontificia Universidad Católica Argentina Sant...      18
# 124  Privado                              Universidad  Favaloro      19
# 128  Privado                 Universidad Abierta Interamericana      20
# 143  Privado                Universidad Argentina de la Empresa      21
# 151  Privado              Universidad Argentina John F. Kennedy      22
# 193  Privado                                  Universidad CAECE      23
# 206  Privado                            Universidad de Belgrano      26
# 222  Público                        Universidad de Buenos Aires      27
# 247  Privado   Universidad de Ciencias Empresariales y Sociales      28
# 260  Privado                              Universidad de Flores      29
# 267  Privado                  Universidad de la Marina Mercante      30
# 284  Privado                             Universidad de Palermo      32
# 292  Privado                               Universidad del CEMA      34
# 309  Privado                               Universidad del Cine      35
# 312  Privado             Universidad del Museo Social Argentino      36
# 319  Privado                           Universidad del Salvador      38
# 336  Privado                                 Universidad ISALUD      39
# 344  Privado                             Universidad Maimónides      40
# 348  Privado  Universidad Metropolitana para la Educación y ...      41
# 359  Público                  Universidad Nacional de las Artes      43
# 377  Público                   Universidad Tecnológica Nacional      49
# 382  Privado                      Universidad Torcuato Di Tella      50
# 392  Privado                  Universitá Degli Studi di Bologna      51
#
#     unidad_aca  unac_c  anexo_c   unicue   cui  \
# 0    Rectorado       1        0   100100  2546
# 1    Rectorado       1        0   200100  2456
# 28   Rectorado       1        0   400100  2461
# 31   Rectorado       1        0   500100  2462
# 33   Rectorado       1        0   600100   211
# 35   Rectorado       1        0   700100  2284
# 53   Rectorado       1        0   800100  2545
# 59   Rectorado       1        0   900100  1858
# 61   Rectorado       1        0  1000100  2228
# 64   Rectorado       1        0  1100100  2469
# 72   Rectorado       1        0  1200100  2468
# 81   Rectorado       1        0  1300100  1457
# 88   Rectorado       1        0  1400100  2467
# 94   Rectorado       1        0  1500100  2466
# 104  Rectorado       1        0  1700100  1464
# 107  Rectorado       1        0  1800100  2464
# 124  Rectorado       1        0  1900100  2475
# 128  Rectorado       1        0  2000100  2476
# 143  Rectorado       1        0  2100100  2477
# 151  Rectorado       1        0  2200100  2481
# 193  Rectorado       1        0  2300100  2483
# 206  Rectorado       1        0  2600100  2559
# 222  Rectorado       1        0  2700100  2502
# 247  Rectorado       1        0  2800100  2504
# 260  Rectorado       1        0  2900100  2519
# 267  Rectorado       1        0  3000100  2510
# 284  Rectorado       1        0  3200100  2515
# 292  Rectorado       1        0  3400100  2522
# 309  Rectorado       1        0  3500100  2523
# 312  Rectorado       1        0  3600100  2524
# 319  Rectorado       1        0  3800100  2531
# 336  Rectorado       1        0  3900100  2537
# 344  Rectorado       1        0  4000100  2539
# 348  Rectorado       1        0  4100100  2540
# 359  Rectorado       1        0  4300100  2542
# 377  Rectorado       1        0  4900100  2555
# 382  Rectorado       1        0  5000100  2556
# 392  Rectorado       1        0  5100100  1050
#
#                                 telef                    fax    ...      \
# 0              5238-9339 (C)5238-9300              4375-1373    ...
# 1               63934813 [C]6393-4810              6393-4813    ...
# 28                          5299-0196              5299-0196    ...
# 31              (C)4800-0200 Int. 239  (C)4800-0200 Int. 239    ...
# 33                          5169-3345              5169-3345    ...
# 35        4905-5014/5012 [C]4905-5000              4905-5014    ...
# 53    475-7867/7985 Int.19 /4899-1607               475-7867    ...
# 59                   4576-7611/Int.39              4576-7611    ...
# 61             4576-5652 [C]4576-5650              4576-5652    ...
# 64                5032-3900/5032-3991              5353-9099    ...
# 72             [C]4959-0200 Int. 4161              4983-2624    ...
# 81                4773-5825/4773-3735              4773-3735    ...
# 88                     4632-5030/5039              4633-2825    ...
# 94                          5032-4922              4382-4039    ...
# 104                    4789-1141/1142              4789-1141    ...
# 107    4349-0251[C]4349-0200/43380600              4349-0273    ...
# 124                    4378-1169/1170              4381-0323    ...
# 128               4342-7788/4363-3581               442-7654    ...
# 143             4000-7601[C]4000-7600              4381-3850    ...
# 151                    5236-1216/1242              5236-1216    ...
# 193            5252-2817 (C)5252-2800              5217-7886    ...
# 206             4576-3928(C)4788-5400              4576-3923    ...
# 222  4511-8153 (C)4510-1100 Int. 1204              4510-1213    ...
# 247                 4815-3290 Int.371              4815-3290    ...
# 260            4610-9050 [C]4611-4800              4610-9050    ...
# 267               4953-9000/4952-4700              4953-9000    ...
# 284                5199-4500 Int.2500              4963-1560    ...
# 292                      (C)6314-3000              6314-1654    ...
# 309            (R)4300-1413/4300-1407              4300-0674    ...
# 312               5530-7600/5530-7603              5530-7614    ...
# 319                    4813-1408/9630              4812-4625    ...
# 336                      (C)5239-4000              5279-4020    ...
# 344    4373-1090/4905-1154 /4382-7510              4373-1090    ...
# 348               5354-6669 Int. 7711              5354-6669    ...
# 359        5777-1363/1364[C]5777-1300              5777-1363    ...
# 377                    5371-5700/5702              5371-5697    ...
# 382             5169-7168[C]5169-7000              5169-7240    ...
# 392          [C]4570-3000 Int.140/141              4570-3059    ...
#
#                       direccion_norm                        calle altura  \
# 0                       Ayacucho 555                    Ayacucho     555
# 1             Av. Eduardo Madero 399          Av. Eduardo Madero     399
# 28                   Valdenegro 4337                  Valdenegro    4337
# 31                Av. Las Heras 2191               Av. Las Heras    2191
# 33               Av. Paseo Colón 533             Av. Paseo Colón     533
# 35                       Rosario 532                     Rosario     532
# 53                        Maure 1850                       Maure    1850
# 59                Av. Corrientes 345              Av. Corrientes     345
# 61                    Av. Cabildo 15                 Av. Cabildo      15
# 64                  Av. Córdoba 1690                 Av. Córdoba    1690
# 72                       Potosí 4240                      Potosí    4240
# 81                      Uriarte 2472                     Uriarte    2472
# 88                       Camacuá 282                     Camacuá     282
# 94            Hipólito Yrigoyen 1584           Hipólito Yrigoyen    1584
# 104   Av. Pte. Figueroa Alcorta 7597   Av. Pte. Figueroa Alcorta    7597
# 107  Av. Alicia Moreau de Justo 1300  Av. Alicia Moreau de Justo    1300
# 124                        Solís 453                       Solís     453
# 128                     Chacabuco 90                   Chacabuco      90
# 143                         Lima 717                        Lima     717
# 151             Bartolomé Mitre 1411             Bartolomé Mitre    1411
# 193                        Junín 516                       Junín     516
# 206                      Zabala 1837                      Zabala    1837
# 222                     Viamonte 427                    Viamonte     427
# 247                     Libertad 926                    Libertad     926
# 260                    Av. Nazca 274                   Av. Nazca     274
# 267               Av. Rivadavia 2258               Av. Rivadavia    2258
# 284                 Mario Bravo 1050                 Mario Bravo    1050
# 292                  Av. Córdoba 374                 Av. Córdoba     374
# 309               Pasaje Giuffra 330              Pasaje Giuffra     330
# 312              Av. Corrientes 1723              Av. Corrientes    1723
# 319                    Viamonte 1856                    Viamonte    1856
# 336                    Venezuela 931                   Venezuela     931
# 344                   Talcahuano 456                  Talcahuano     456
# 348                   Sarmiento 2037                   Sarmiento    2037
# 359                   Azcuénaga 1129                   Azcuénaga    1129
# 377                    Sarmiento 440                   Sarmiento     440
# 382   Av. Pte. Figueroa Alcorta 7350   Av. Pte. Figueroa Alcorta    7350
# 392        Marcelo T. de Alvear 1149        Marcelo T. de Alvear    1149
#
#                                         WKT_gkba         barrio     comuna  \
# 0    POINT (-58.3953412190814 -34.6026584750106)      Balvanera   Comuna 3
# 1    POINT (-58.3678488464698 -34.6031162314776)  Puerto Madero   Comuna 1
# 28   POINT (-58.4948843800369 -34.5549371768609)       Saavedra  Comuna 12
# 31   POINT (-58.3955408860349 -34.5885162878714)       Recoleta   Comuna 2
# 33   POINT (-58.3696771407485 -34.6142939728233)      Monserrat   Comuna 1
# 35   POINT (-58.4361507684532 -34.6196283863132)      Caballito   Comuna 6
# 53   POINT (-58.4369004669905 -34.5679143258642)        Palermo  Comuna 14
# 59   POINT (-58.3716709807457 -34.6029709783307)    San Nicolas   Comuna 1
# 61    POINT (-58.4363411902568 -34.574260414171)        Palermo  Comuna 14
# 64    POINT (-58.391144567227 -34.5993687939657)       Recoleta   Comuna 2
# 72   POINT (-58.4267801919644 -34.6073823354498)        Almagro   Comuna 5
# 81   POINT (-58.4231180248877 -34.5808345005318)        Palermo  Comuna 14
# 88   POINT (-58.4570505249903 -34.6308476883879)         Flores   Comuna 7
# 94    POINT (-58.388675220497 -34.6102170015096)      Monserrat   Comuna 1
# 104  POINT (-58.4493832944056 -34.5464218660769)       Belgrano  Comuna 13
# 107   POINT (-58.3660165289871 -34.613576848636)  Puerto Madero   Comuna 1
# 124  POINT (-58.3904785097825 -34.6143704479052)      Monserrat   Comuna 1
# 128  POINT (-58.3762527525278 -34.6091537387281)      Monserrat   Comuna 1
# 143  POINT (-58.3818071323537 -34.6167932966567)      Monserrat   Comuna 1
# 151  POINT (-58.3864416149974 -34.6075104253149)    San Nicolas   Comuna 1
# 193  POINT (-58.3970854586574 -34.6031031020606)      Balvanera   Comuna 3
# 206  POINT (-58.3715880886931 -34.5866795404173)         Retiro   Comuna 1
# 222  POINT (-58.3729066861741 -34.5995726282451)    San Nicolas   Comuna 1
# 247    POINT (-58.384216501586 -34.597818935354)         Retiro   Comuna 1
# 260  POINT (-58.4707937934327 -34.6287071418312)         Flores   Comuna 7
# 267   POINT (-58.3983730130022 -34.609827597834)      Balvanera   Comuna 3
# 284  POINT (-58.4159198715708 -34.5972163309537)        Palermo  Comuna 14
# 292  POINT (-58.3723604181354 -34.5986727036622)    San Nicolas   Comuna 1
# 309  POINT (-58.3708577957347 -34.6167492120501)      San Telmo   Comuna 1
# 312  POINT (-58.3912206851556 -34.6041679736257)    San Nicolas   Comuna 1
# 319  POINT (-58.3935571895913 -34.6009493451979)      Balvanera   Comuna 3
# 336  POINT (-58.3794334747706 -34.6140639392269)      Monserrat   Comuna 1
# 344  POINT (-58.3852701943361 -34.6031762026456)    San Nicolas   Comuna 1
# 348  POINT (-58.3957335603489 -34.6057821832057)      Balvanera   Comuna 3
# 359  POINT (-58.3996900447348 -34.5949024197786)       Recoleta   Comuna 2
# 377  POINT (-58.3729913230506 -34.6044855456125)    San Nicolas   Comuna 1
# 382  POINT (-58.4473918076942 -34.5481966747009)       Belgrano  Comuna 13
# 392  POINT (-58.3835621148359 -34.5967589513622)         Retiro   Comuna 1
#
#     codigo_postal  codigo_postal_argentino       long        lat
# 0          1026.0                 C1026AAC -58.395341 -34.602658
# 1          1106.0                 C1106ACD -58.367849 -34.603116
# 28         1430.0                 C1430EFA -58.494884 -34.554937
# 31         1127.0                 C1127AAD -58.395541 -34.588516
# 33         1063.0                 C1063ACF -58.369677 -34.614294
# 35         1424.0                 C1424CCL -58.436151 -34.619628
# 53         1426.0                 C1426CUH -58.436900 -34.567914
# 59         1043.0                 C1043AAD -58.371671 -34.602971
# 61         1426.0                 C1426AAA -58.436341 -34.574260
# 64         1055.0                 C1055AAT -58.391145 -34.599369
# 72         1199.0                 C1199ACL -58.426780 -34.607382
# 81         1425.0                 C1425FNJ -58.423118 -34.580835
# 88         1406.0                 C1406DOF -58.457051 -34.630848
# 94         1089.0                 C1089AAD -58.388675 -34.610217
# 104        1428.0                 C1428BCL -58.449383 -34.546422
# 107        1107.0                 C1107AAZ -58.366017 -34.613577
# 124        1078.0                 C1078AAI -58.390479 -34.614370
# 128        1069.0                 C1069AAB -58.376253 -34.609154
# 143        1073.0                 C1073AAO -58.381807 -34.616793
# 151        1037.0                 C1037ABA -58.386442 -34.607510
# 193        1026.0                 C1026ABL -58.397085 -34.603103
# 206        1426.0                 C1426DQG -58.371588 -34.586680
# 222        1053.0                 C1053ABI -58.372907 -34.599573
# 247        1012.0                 C1012AAT -58.384217 -34.597819
# 260        1406.0                 C1406AJO -58.470794 -34.628707
# 267        1034.0                 C1034ACO -58.398373 -34.609828
# 284        1175.0                 C1175ABT -58.415920 -34.597216
# 292        1054.0                 C1054AAP -58.372360 -34.598673
# 309        1064.0                 C1064ADD -58.370858 -34.616749
# 312        1042.0                 C1042AAD -58.391221 -34.604168
# 319        1056.0                 C1056ABB -58.393557 -34.600949
# 336        1095.0                 C1095AAS -58.379433 -34.614064
# 344        1013.0                 C1013AAJ -58.385270 -34.603176
# 348        1044.0                 C1044AAE -58.395734 -34.605782
# 359        1115.0                 C1115AAG -58.399690 -34.594902
# 377        1041.0                 C1041AAJ -58.372991 -34.604486
# 382        1428.0                 C1428BCW -58.447392 -34.548197
# 392        1058.0                 C1058AAQ -58.383562 -34.596759
#
# [38 rows x 21 columns]

# %% [markdown]
# Ya que estamos jugando, vamos a ver cuáles son las universidades

# %%
universidades = universidades_data['universida'].unique()
len(universidades)
# Out:
# 51

# %%
print(universidades)
# Out:
# ['FLACSO (Facultad Latinoamericana de Ciencias Sociales)'
#  'Instituto Tecnológico de Buenos Aires'
#  'Instituto Universitario Aeronáutico' 'Instituto Universitario CEMIC'
#  'Instituto Universitario de Ciencias de la Salud de la Fundación Barceló'
#  'Instituto Universitario de Gendarmería Nacional'
#  'Instituto Universitario de la Policía Federal Argentina'
#  'Instituto Universitario de Salud Mental de la Asociación Psicoanalítica de Buenos Aires'
#  'Instituto Universitario de Seguridad Marítima'
#  'Instituto Universitario del Ejército "Mayor Francisco Romero"'
#  'Instituto Universitario Escuela Argentina de Negocios'
#  'Instituto Universitario Escuela de Medicina del Hospital Italiano'
#  'Instituto Universitario Escuela Superior de Economía y Administración de Empresas'
#  'Instituto Universitario ISEDET'
#  'Instituto Universitario Nacional de Derechos Humanos "Madres de Plaza de Mayo"'
#  'Instituto Universitario Naval' 'Instituto Universitario River Plate'
#  'Pontificia Universidad Católica Argentina Santa María de los Buenos Aires'
#  'Universidad  Favaloro' 'Universidad Abierta Interamericana'
#  'Universidad Argentina de la Empresa'
#  'Universidad Argentina John F. Kennedy' 'Universidad CAECE'
#  'Universidad Católica de La Plata' 'Universidad Católica de Salta'
#  'Universidad de Belgrano' 'Universidad de Buenos Aires'
#  'Universidad de Ciencias Empresariales y Sociales'
#  'Universidad de Flores' 'Universidad de la Marina Mercante'
#  'Universidad de Morón' 'Universidad de Palermo'
#  'Universidad de San Andrés' 'Universidad del CEMA' 'Universidad del Cine'
#  'Universidad del Museo Social Argentino'
#  'Universidad del Norte Santo Tomás de Aquino' 'Universidad del Salvador'
#  'Universidad ISALUD' 'Universidad Maimónides'
#  'Universidad Metropolitana para la Educación y el Trabajo'
#  'Universidad Nacional de la Matanza' 'Universidad Nacional de las Artes'
#  'Universidad Nacional de Luján' 'Universidad Nacional de Quilmes'
#  'Universidad Nacional de San Martín'
#  'Universidad Nacional de Tres de Febrero'
#  'Universidad Pedagógica de la Provincia de Buenos Aires'
#  'Universidad Tecnológica Nacional' 'Universidad Torcuato Di Tella'
#  'Universitá Degli Studi di Bologna']

# %% [markdown]
# Con la información de rectorados, y la de universidades, ahora quiero ver si todas las universidades tienen rectorado. Una forma trucha de hacerlo es verificar que ambos listados tienen la misma longitud:

# %%
if (len(universidades) == len(rectorados)):
  print('Sin iguales')
elif (len(universidades) > len(rectorados)):
  print('Hay universidades que no tienen rectorados')
else:
  print('Alguna universidad tiene más de un rectorado. Raro che.')
# Out:
# Hay universidades que no tienen rectorados

# %%
print(len(rectorados))
print(len(universidades))
# Out:
# 38
# 51

# %% [markdown]
# Ahora voy a jugar con folium, una librería que encontré que puede servir para mostrar información geolocalizada (el CSV tiene información de latitud y longitud)

# %%
import folium

# %% [markdown]
# Le digo a folium que me cree un mapa, centrado en CABA, y con un toque de zoom para ver bien la ciudad

# %%
map_osm = folium.Map(location=[-34.5941696,-58.4583627], zoom_start=12)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ahora voy a iterar sobre el listado de universidades, para marcar en el mapa donde están las distintas sedes. Pongo circulitos para las sedes

# %%
universidades_data.apply(lambda row:folium.CircleMarker(location=[row["lat"], 
                                                  row["long"]]).add_to(map_osm),
         axis=1)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Y ahora haré lo mismo con los rectorados, para contrastar donde tienen los rectorados las distintas universidades. Pongo marcadores típicos para los rectorados

# %%
rectorados.apply(lambda row:folium.Marker(location=[row["lat"], 
                                                  row["long"]]).add_to(map_osm),
         axis=1)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
